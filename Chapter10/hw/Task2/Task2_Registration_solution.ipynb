# %% [markdown]
# # Task2: Exploring Unsupervised Registration using Voxelmorph
#
# Medical image registration has been a cornerstone in the research fields of medical image computing and computer assisted intervention, responsible for many clinical applications. Whilst machine learning methods have long been important in developing pairwise algorithms, recently proposed deep-learning-based frameworks directly infer displacement fields without iterative optimisation for unseen image pairs, using neural networks trained from large population data. These novel approaches promise to tackle several most challenging aspects previously faced by classical pairwise methods, such as high computational cost, robustness for generalisation and lack of inter-modality similarity measures.
#
# Note the package makes use of  `Neurite`, a neural networks toolbox that is based on Tensorflow rather than Pytorch. **Due to compatibility issues, you must make the following changes:**
#
# 1. Follow https://github.com/tensorflow/tensorflow/issues/70796 so that `import voxelmorph` can be run successfully.
# 2. Replace all `get_shape()` with `shape` in the `<voxelmorph package>/tf/networks.py` .

# %% [markdown]
# ## Registration1: MNIST Dataset
#
# ### Loading the Dataset
#
# We will learn the preliminearies about (unsupervised) DL image registration through the simple MNIST dataset and the popular *VoxelMorph* framework. VoxelMorph is a fast learning-based framework for deformable, pairwise medical image registration. Instead of optimizing an objective function for each pair of images which can be time-consuming, it formulates registration as a function that maps an input image to a deformation field that aligns these images. Given a new pair of scans, VoxelMorph rapidly computes a deformation field by directly evaluating the function.
#
# > Balakrishnan, Guha, et al. “VoxelMorph: A Learning Framework for Deformable Medical Image Registration.” IEEE Transactions on Medical Imaging, vol. 38, no. 8, Aug. 2019, pp. 1788–800. DOI.org (Crossref), https://doi.org/10.1109/TMI.2019.2897538.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
os.environ['TF_USE_LEGACY_KERAS'] = '1'

# %%
import neurite as ne
import voxelmorph as vxm
# Out:
# 2024-11-01 13:01:53.298585: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:01:53.298599: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from torchvision import datasets

train_loader = datasets.MNIST('../data', train=True, download=True)
test_loader = datasets.MNIST('../data', train=False, download=True)

# %%
x_train = np.array([np.array(image) for image, _ in train_loader])
y_train = np.array([label for _, label in train_loader], dtype=object)
x_test = np.array([np.array(image) for image, _ in test_loader])
y_test = np.array([label for _, label in test_loader], dtype=object)

# Create validation set as well
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]

# let's get some shapes to understand what we loaded.
print('shape of x_train: ', x_train.shape)
print('shape of y_train: ', y_train.shape)
print('shape of x_val: ', x_val.shape)
print('shape of y_val: ', y_val.shape)
print('shape of x_test: ', x_test.shape)
print('shape of y_test: ', y_test.shape)
# Out:
# shape of x_train:  (50000, 28, 28)
# shape of y_train:  (50000,)
# shape of x_val:  (10000, 28, 28)
# shape of y_val:  (10000,)
# shape of x_test:  (10000, 28, 28)
# shape of y_test:  (10000,)

# %%
# We select first 5 images from the training set and visualize them

fig, ax = plt.subplots(1, 5, figsize=(15, 5))
for i in range(5):
    ax[i].imshow(x_train[i], cmap='gray')
    ax[i].axis('off')
    ax[i].set_title('Label: ' + str(y_train[i]))

# %% [markdown]
# As the last step of loading, we pre-process the data to make it suitable for the VoxelMorph framework.  For demonstration, we will create a stand alone dataset that **contains only number 4, 5, 7**.

# %%
x_train = x_train/255
x_val = x_val/255
x_test = x_test/255

# Change size from 28*28 to 32*32
pad_amount = ((0, 0), (2,2), (2,2))
x_train = np.pad(x_train, pad_amount, 'constant') # pad with constant values
x_val = np.pad(x_val, pad_amount, 'constant')
x_test = np.pad(x_test, pad_amount, 'constant')

# %%
x_train_4 = x_train[y_train == 4]
x_val_4 = x_val[y_val == 4]
x_test_4 = x_test[y_test == 4]

x_train_5 = x_train[y_train == 5]
x_val_5 = x_val[y_val == 5]
x_test_5 = x_test[y_test == 5]

x_train_7 = x_train[y_train == 7]
x_val_7 = x_val[y_val == 7]
x_test_7 = x_test[y_test == 7]

# %%
# visualize again
fig, ax = plt.subplots(1, 5, figsize=(15, 5))
for i in range(5):
    ax[i].imshow(x_train_7[i], cmap='gray')
    ax[i].axis('off')

# %% [markdown]
# ### Defining Neural Networks used to Estimate Deformation
#
# In learning-based methods, we use a neural network that takes in two images $m$ and $f$ (e.g. MNIST digits of size 32x32) and outputs a dense deformation $\phi$ (e.g. size 32x32x2, because at each pixel we want a vector telling us where to go). In this case, we abstract the UNet model from the VoxelMorph.
#
# Note that we only consider non-rigid deformation here as there are lots of handy tools to conduct affine registrations.

# %%
N_DIM = 2
INPUT_FEATURES = 2

input_shape = (*x_train.shape[1:], INPUT_FEATURES)
print('input shape: ', input_shape)

n_encoder_features = [32, 32, 32, 32]
n_decoder_features = [32, 32, 32, 32, 32, 16]
n_features = [n_encoder_features, n_decoder_features]

# inshape: Input tensor shape
# nb_features: UNet convolutional features, specified via a list of lists of the form [[encoder feats], [decoder feats]]
UNet = vxm.networks.Unet(inshape=input_shape, nb_features=n_features)

print(f"Shape of input: {UNet.input[0].shape}")
print(f"Shape of output: {UNet.output[0].shape}")
# Out:
# input shape:  (32, 32, 2)
# Shape of input: (32, 32, 2)
# Shape of output: (32, 32, 16)
# 2024-11-01 13:02:16.982215: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2024-11-01 13:02:17.096345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1c:00.0 name: NVIDIA A100-SXM4-80GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 79.14GiB deviceMemoryBandwidth: 1.85TiB/s
# 2024-11-01 13:02:17.096512: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:02:17.098639: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:02:17.100511: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:02:17.102376: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:02:17.102394: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2024-11-01 13:02:17.104430: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:02:17.107333: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:02:17.108853: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /work/users/y/u/yuukias/env_conda/lib:/nas/longleaf/rhel8/apps/r/4.1.0/lib64/R/lib
# 2024-11-01 13:02:17.108859: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-11-01 13:02:17.109309: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-01 13:02:17.109583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-11-01 13:02:17.109586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]

# %% [markdown]
# We can then use the UNet to replicate the structure presented in VoxelMorph.

# %%
# Deformation Model: UNet + Conv2D
class DeformationModel(nn.Module):
    def __init__(self, UNet, N_DIM):
        super(DeformationModel, self).__init__()
        self.unet = UNet
        self.conv = nn.Conv2d(in_channels=UNet.output, out_channels=N_DIM, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.UNet(x)
        deformation_tensor = self.conv(x)
        return deformation_tensor

# %%
# Full Model: UNet + Conv2D + Spatial Transformer
class VoxelMorphModel(nn.Module):
    def __init__(self, UNet, N_DIM):
        super(VoxelMorphModel, self).__init__()
        self.deformation_model = DeformationModel(UNet, N_DIM)
        self.spatial_transformer = vxm.layers.SpatialTransformer(name='transformer')

    def forward(self, x):
        deformation_tensor = self.deformation_model(x)
        moved_image_tensor = self.spatial_transformer([x, deformation_tensor])
        out_tensor = [moved_image_tensor, deformation_tensor]
        return out_tensor

# %% [markdown]
# The model we just created represents the standard, dense VoxelMorph archetecture, with **a UNet component, displacement field, and final spatial transformer layer**.
#
# <img src="../img/VoxelMorph.png" width="800" height="400">
#
# Actually, it is not necessary for us to repeat such code every time. Voxelmorph has a built-in `VxmDense` class to define such models.

# %%
# We no longer need to supply 2 in input_shape, as the model will automatically configured with two input tensorw (moving and fixed inputs) instead of one
vxm_model = vxm.networks.VxmDense(inshape=input_shape[:2], nb_unet_features=n_features, int_steps=0) # Here int_steps=0 option disables diffeomorphism
print(f"Shape of input: {[str(t.shape) for t in vxm_model.inputs]}")
print(f"Shape of output: {[str(t.shape) for t in vxm_model.outputs]}")
# Out:
# WARNING:tensorflow:From /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Shape of input: ['(None, 32, 32, 1)', '(None, 32, 32, 1)']
# Shape of output: ['(None, 32, 32, 1)', '(None, 32, 32, 2)']

# %% [markdown]
# ### Defining Loss Function
#
# In unsupervised registration where no gold standard is provided, how could we know whether the deformation is good or not?
#
# 1. First make sure $m\circ \phi$, that is, the moving image warped by the deformation $\phi$ to be close to the fixed image $f$.
# 2. Then regularize $\phi$, ensuring that the deformation is smooth enough without eccentric behavior.
#
# Let us define two losses: a simple MSE and a spatial gradient of the displacement.

# %%
# voxelmorph has a variety of custom loss classes
losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]
lambda_param = 0.05
loss_weights = [1, lambda_param]  # balance the two losses through hyperparameter

vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights)

# %% [markdown]
# ### Train the Model
#
# After making an instance of model, we need to make sure the data is in the right format through a python generator that gives batches of data.

# %%
def vxm_data_generator(x, batch_size=32):
    """
    Generator that takes in data of size [N, H, W], and yields data for
    our custom vxm model. Note that we need to provide numpy data for each
    input, and each output.

    inputs:  moving [bs, H, W, 1], fixed image [bs, H, W, 1]
    outputs: moved image [bs, H, W, 1], zero-gradient [bs, H, W, 2]
    """

    # preliminary sizing
    volume_shape = x.shape[1:] # extract data shape
    n_dim = len(volume_shape)
    
    # prepare a zero array the size of the deformation, explained later
    zero_phi = np.zeros([batch_size, *volume_shape, n_dim])
    
    while True:
        # randomly select pairs of images for training
        idx1 = np.random.randint(0, x.shape[0], size=batch_size)
        moving_images = x[idx1, ..., np.newaxis]
        idx2 = np.random.randint(0, x.shape[0], size=batch_size)
        fixed_images = x[idx2, ..., np.newaxis]

        inputs = [moving_images, fixed_images]
        outputs = [fixed_images, zero_phi]
        
        yield (inputs, outputs)

# %%
# Make use of the generator
train_generator = vxm_data_generator(x_train_7)
in_sample, out_sample = next(train_generator)

print(in_sample[0].shape)
images = [img[0, :, :, 0] for img in in_sample + out_sample] 
titles = ['Moving', 'Fixed', 'Moved ground-truth (Fixed)', 'Zero Deformation Field']
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    ax[i].imshow(images[i], cmap='gray')
    ax[i].axis('off')
    ax[i].set_title(titles[i])
# Out:
# (32, 32, 32, 1)

# %%
epochs = 10
steps_per_epoch = 100
history = vxm_model.fit_generator(train_generator, epochs=epochs, steps_per_epoch=steps_per_epoch, verbose=2);
# Out:
# /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2024-11-01 13:02:18.353166: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2024-11-01 13:02:18.365798: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2800000000 Hz
# Epoch 1/10
# 100/100 - 8s - loss: 0.0364 - vxm_dense_transformer_loss: 0.0340 - vxm_dense_flow_loss: 0.0473
# Epoch 2/10
# 100/100 - 7s - loss: 0.0130 - vxm_dense_transformer_loss: 0.0093 - vxm_dense_flow_loss: 0.0741
# Epoch 3/10
# 100/100 - 7s - loss: 0.0100 - vxm_dense_transformer_loss: 0.0065 - vxm_dense_flow_loss: 0.0704
# Epoch 4/10
# 100/100 - 7s - loss: 0.0090 - vxm_dense_transformer_loss: 0.0056 - vxm_dense_flow_loss: 0.0684
# Epoch 5/10
# 100/100 - 7s - loss: 0.0081 - vxm_dense_transformer_loss: 0.0048 - vxm_dense_flow_loss: 0.0666
# Epoch 6/10
# 100/100 - 7s - loss: 0.0080 - vxm_dense_transformer_loss: 0.0047 - vxm_dense_flow_loss: 0.0642
# Epoch 7/10
# 100/100 - 7s - loss: 0.0074 - vxm_dense_transformer_loss: 0.0043 - vxm_dense_flow_loss: 0.0633
# Epoch 8/10
# 100/100 - 7s - loss: 0.0070 - vxm_dense_transformer_loss: 0.0039 - vxm_dense_flow_loss: 0.0617
# Epoch 9/10
# 100/100 - 7s - loss: 0.0070 - vxm_dense_transformer_loss: 0.0039 - vxm_dense_flow_loss: 0.0625
# Epoch 10/10
# 100/100 - 7s - loss: 0.0066 - vxm_dense_transformer_loss: 0.0036 - vxm_dense_flow_loss: 0.0603

# %%
# Visualize the loss
plt.figure()
plt.plot(history.epoch, history.history['loss'], '.-')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Start Registration

# %%
# test the trained model using validation set
val_generator = vxm_data_generator(x_val_7, batch_size = 1)
val_input, _ = next(val_generator)
val_pred = vxm_model.predict(val_input)

# %%
# visualize the prediction
images = [img[0, :, :, 0] for img in val_input + val_pred] 
titles = ['Moving', 'Fixed', 'Moved', 'Flow']
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    ax[i].imshow(images[i], cmap='gray')
    ax[i].axis('off')
    ax[i].set_title(titles[i])

# %% [markdown]
# The visualization of flow field might be a bit tricky. The `neurite` package provides a handy function `plot.flow` to visualize the displacement field.

# %%
ne.plot.flow([val_pred[1].squeeze()], width=4)
# Out:
# (<Figure size 400x400 with 1 Axes>, [<Axes: >])

# %% [markdown]
# Then you might wonder, can we use the learned model for other numbers such as 4 or 5? Let us make some experiments.

# %%
val_generator = vxm_data_generator(x_val_4, batch_size = 1)
val_input, _ = next(val_generator)
val_pred = vxm_model.predict(val_input)

# visualize the prediction
images = [img[0, :, :, 0] for img in val_input + val_pred]
titles = ['Moving', 'Fixed', 'Moved', 'Flow']
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    ax[i].imshow(images[i], cmap='gray')
    ax[i].axis('off')
    ax[i].set_title(titles[i])

# %%
val_generator = vxm_data_generator(x_val_5, batch_size = 1)
val_input, _ = next(val_generator)
val_pred = vxm_model.predict(val_input)

# visualize the prediction
images = [img[0, :, :, 0] for img in val_input + val_pred]
titles = ['Moving', 'Fixed', 'Moved', 'Flow']
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    ax[i].imshow(images[i], cmap='gray')
    ax[i].axis('off')
    ax[i].set_title(titles[i])

# %% [markdown]
# Interesting - it still works with a bit worse performance, meaning that it generalizes beyond what we expected. Why? Locally, parts of the 7s look similar to the 4s as well as 5s, so the registration algorithm still tries to match local neighborhoods.

# %% [markdown]
# ## Registration2: Brain MRI
#
# Cleary MNIST is just a toy dataset. Let us try a more realistic example - brain MRI images. You can find them in `data/Brain`.
#
# These brain images have gone through intensity-normalized affinely alignment, and are skull-stripped with FreeSurfer, so that we can focus on deformable registration only.

# %%
brain_data = np.load('../data/Brain/tutorial_data.npz')
x_train = brain_data['train']
x_val = brain_data['validate']

# There are 208 volumes, each of size 160x192
volume_shape = x_train.shape[1:]
print('Shape of x_train:', x_train.shape)
# Out:
# Shape of x_train: (208, 192, 160)

# %%
# Make some visualizations for first 5 volumes
fig, ax = plt.subplots(1, 5, figsize=(20, 5))
for i in range(5):
    ax[i].imshow(x_train[i, ...], cmap = 'gray')
    ax[i].axis('off')
    cbar = plt.colorbar(ax[i].imshow(x_train[i, ...], cmap='gray'), ax=ax[i])
    cbar.ax.tick_params(labelsize=8)

# %% [markdown]
# We will repeat the same setting as above for the MNIST dataset, with the tunning parameter adjusted to 0.01.

# %%
# Prepare the VoxelMorph model
# todo
vxm_model = vxm.networks.VxmDense(volume_shape, n_features, int_steps=0)

losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]
lambda_param = 0.01
loss_weights = [1, lambda_param]

vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights)

# %%
# Prepare the data generator
# todo
train_generator = vxm_data_generator(x_train, batch_size=8)
in_sample, out_sample = next(train_generator)

# visualize
# todo
# Hint: Follow the same procedure as in the MNIST example
images = [img[0, :, :, 0] for img in in_sample + out_sample]
titles = ['Moving', 'Fixed', 'Moved ground-truth (fixed)', 'Zero Deformation Field']
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    ax[i].imshow(images[i], cmap='gray')
    ax[i].axis('off')
    ax[i].set_title(titles[i])

# %% [markdown]
# As the brains are much more complex than the MNIST digits, the `epochs` should be increased to 200. We adjust `steps_per_epoch` to $\lceil 208/8\rceil=26$.

# %%
epochs = 200
steps_per_epoch = 26
# todo
history = vxm_model.fit_generator(train_generator, epochs=epochs, steps_per_epoch=steps_per_epoch, verbose=2);
# Out:
# Epoch 1/200
# 26/26 - 11s - loss: 0.0022 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0728
# Epoch 2/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0697
# Epoch 3/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0736
# Epoch 4/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0722
# Epoch 5/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0701
# Epoch 6/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0732
# Epoch 7/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0724
# Epoch 8/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0698
# Epoch 9/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0711
# Epoch 10/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0719
# Epoch 11/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0734
# Epoch 12/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0730
# Epoch 13/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0705
# Epoch 14/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0701
# Epoch 15/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0691
# Epoch 16/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0698
# Epoch 17/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0710
# Epoch 18/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0708
# Epoch 19/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0695
# Epoch 20/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0700
# Epoch 21/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0736
# Epoch 22/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0707
# Epoch 23/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0689
# Epoch 24/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0713
# Epoch 25/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0710
# Epoch 26/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0741
# Epoch 27/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0749
# Epoch 28/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0713
# Epoch 29/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0728
# Epoch 30/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0699
# Epoch 31/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0691
# Epoch 32/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0702
# Epoch 33/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0732
# Epoch 34/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0721
# Epoch 35/200
# 26/26 - 15s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0728
# Epoch 36/200
# 26/26 - 14s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0704
# Epoch 37/200
# 26/26 - 12s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0727
# Epoch 38/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0702
# Epoch 39/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0680
# Epoch 40/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0709
# Epoch 41/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0732
# Epoch 42/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0706
# Epoch 43/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0709
# Epoch 44/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0714
# Epoch 45/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0690
# Epoch 46/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0740
# Epoch 47/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0696
# Epoch 48/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0701
# Epoch 49/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0742
# Epoch 50/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0714
# Epoch 51/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0720
# Epoch 52/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0694
# Epoch 53/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0713
# Epoch 54/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0703
# Epoch 55/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0696
# Epoch 56/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0745
# Epoch 57/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0712
# Epoch 58/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0724
# Epoch 59/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0705
# Epoch 60/200
# 26/26 - 11s - loss: 0.0021 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0738
# Epoch 61/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0730
# Epoch 62/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0703
# Epoch 63/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0712
# Epoch 64/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0748
# Epoch 65/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0699
# Epoch 66/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0738
# Epoch 67/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0716
# Epoch 68/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0718
# Epoch 69/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0708
# Epoch 70/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0723
# Epoch 71/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0705
# Epoch 72/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0669
# Epoch 73/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0729
# Epoch 74/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0727
# Epoch 75/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0719
# Epoch 76/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0731
# Epoch 77/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0728
# Epoch 78/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0744
# Epoch 79/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0726
# Epoch 80/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0722
# Epoch 81/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0704
# Epoch 82/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0750
# Epoch 83/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0708
# Epoch 84/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0718
# Epoch 85/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0704
# Epoch 86/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0703
# Epoch 87/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0708
# Epoch 88/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0713
# Epoch 89/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0712
# Epoch 90/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715
# Epoch 91/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0713
# Epoch 92/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0703
# Epoch 93/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0701
# Epoch 94/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0703
# Epoch 95/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0706
# Epoch 96/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0683
# Epoch 97/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0699
# Epoch 98/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0702
# Epoch 99/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0693
# Epoch 100/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0692
# Epoch 101/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0711
# Epoch 102/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0723
# Epoch 103/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0677
# Epoch 104/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0764
# Epoch 105/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0688
# Epoch 106/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0704
# Epoch 107/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0709
# Epoch 108/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715
# Epoch 109/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0706
# Epoch 110/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0711
# Epoch 111/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0705
# Epoch 112/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0725
# Epoch 113/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0730
# Epoch 114/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0732
# Epoch 115/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0695
# Epoch 116/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0728
# Epoch 117/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0711
# Epoch 118/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0701
# Epoch 119/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0725
# Epoch 120/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0708
# Epoch 121/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0695
# Epoch 122/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0722
# Epoch 123/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0718
# Epoch 124/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0701
# Epoch 125/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0684
# Epoch 126/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0706
# Epoch 127/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0725
# Epoch 128/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0718
# Epoch 129/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0701
# Epoch 130/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0716
# Epoch 131/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0696
# Epoch 132/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0702
# Epoch 133/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0697
# Epoch 134/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0757
# Epoch 135/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0709
# Epoch 136/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0691
# Epoch 137/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0710
# Epoch 138/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0752
# Epoch 139/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0687
# Epoch 140/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0698
# Epoch 141/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0712
# Epoch 142/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0734
# Epoch 143/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0719
# Epoch 144/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0708
# Epoch 145/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0706
# Epoch 146/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0724
# Epoch 147/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0709
# Epoch 148/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0730
# Epoch 149/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0710
# Epoch 150/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0750
# Epoch 151/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0724
# Epoch 152/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0724
# Epoch 153/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0732
# Epoch 154/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0729
# Epoch 155/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0712
# Epoch 156/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0738
# Epoch 157/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0721
# Epoch 158/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0704
# Epoch 159/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0707
# Epoch 160/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0711
# Epoch 161/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0726
# Epoch 162/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0737
# Epoch 163/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0692
# Epoch 164/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0704
# Epoch 165/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0733
# Epoch 166/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0700
# Epoch 167/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0704
# Epoch 168/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715
# Epoch 169/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715
# Epoch 170/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0747
# Epoch 171/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0707
# Epoch 172/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0734
# Epoch 173/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0704
# Epoch 174/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0731
# Epoch 175/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0690
# Epoch 176/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0706
# Epoch 177/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0709
# Epoch 178/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0691
# Epoch 179/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0724
# Epoch 180/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0723
# Epoch 181/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0738
# Epoch 182/200
# 26/26 - 11s - loss: 0.0019 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0737
# Epoch 183/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0697
# Epoch 184/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0695
# Epoch 185/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0731
# Epoch 186/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0714
# Epoch 187/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0699
# Epoch 188/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0713
# Epoch 189/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0723
# Epoch 190/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0737
# Epoch 191/200
# 26/26 - 11s - loss: 0.0020 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0732
# Epoch 192/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0705
# Epoch 193/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0730
# Epoch 194/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715
# Epoch 195/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0712
# Epoch 196/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0717
# Epoch 197/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0705
# Epoch 198/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0684
# Epoch 199/200
# 26/26 - 11s - loss: 0.0018 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0715
# Epoch 200/200
# 26/26 - 11s - loss: 0.0017 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0696

# %%
# Visualize the loss
plt.figure()
plt.plot(history.epoch, history.history['loss'], '.-')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# todo
val_generator = vxm_data_generator(x_val, batch_size = 1)
val_input, _ = next(val_generator)

val_pred = vxm_model.predict(val_input)

# %%
# Visualize both the images and the flow as before
# todo
images = [img[0, :, :, 0] for img in val_input + val_pred] 
titles = ['Moving', 'Fixed', 'Moved', 'Flow']
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    ax[i].imshow(images[i], cmap='gray')
    ax[i].axis('off')
    ax[i].set_title(titles[i])


flow = val_pred[1].squeeze()[::3,::3]
ne.plot.flow([flow], width=5);

# %% [markdown]
# At first look, the MSE-only model matches the fixed image better. However, we can observe that the obtained deformation field is very noisy and unlikely to be anatomically meaningful. We might need to make use of anatomical segmentations for evaluation.

# %% [markdown]
# ## Concluding Remarks
#
# Here are some tutorials if you want to dive deep into how to use deep learning for medical image registration:
#
# + Visualize warp: https://colab.research.google.com/drive/1F8f1imh5WfyBv-crllfeJBFY16-KHl9c?usp=sharing
# + Template(Atlas) construction: https://colab.research.google.com/drive/1SkQbrWTQHpQFrG4J2WoBgGZC9yAzUas2?usp=sharing#scrollTo=ADanmU8xde-N
#
# Evaluating registration is tricky. For more details, here is a useful reference:
#
# > Song, Joo Hyun. Methods for Evaluating Image Registration. 2017. University of Iowa, Doctor of Philosophy. DOI.org (Crossref), https://doi.org/10.17077/etd.v0vailob.
