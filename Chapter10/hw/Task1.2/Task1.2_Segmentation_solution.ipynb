# %% [markdown]
# # Task1.2: Running nnU-Net
#
# As seen in last task, the vanilla U-Net achives a performance that is not that bad. However, there is always room for more improvement.
#
# In this task, we will use the same dataset, ACDC, as in the previous one. There are many popular variants of the vanilla U-Net, one of which is the nnU-Net. nnU-Net (No New U-Net) is a self-configuring deep learning framework specifically designed for medical image segmentation tasks. It was introduced as a baseline model that autonomously adjusts its architecture, preprocessing, and training pipeline based on the characteristics of a given dataset, making it highly adaptable across different segmentation tasks without requiring manual tuning. Key features of nnUNet include:
#
# + Out-of-the-box Performance: It automatically configures the model to achieve state-of-the-art performance on various datasets without extensive user intervention.
# + Data-Driven Configurations: It customizes aspects like network architecture, patch size, and batch size depending on the size and properties of the input data.
# + Cross-dataset Applicability: nnUNet works well across different datasets and imaging modalities, like MRI, CT, and X-rays.
# + 3D and 2D Models: It supports both 2D and 3D U-Net models, adapting based on dataset dimensionality.
# + Robust Preprocessing: The framework includes built-in data augmentation and normalization techniques to enhance performance and generalization.
#
# <img src="../img/nnU-Net.png" width="800" height="600">
#
# For details of nn-UNet, please refer to the following paper.
#
# > Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring
# method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
#
# You need to run the pipeline on ACDC dataset according to the documentation as described in https://github.com/MIC-DKFZ/nnUNet/tree/master/documentation.

# %% [markdown]
# ## Install nn-UNet

# %%
pip install nnunetv2
# Out:
# Requirement already satisfied: nnunetv2 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (2.5.1)
# Requirement already satisfied: torch>=2.1.2 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (2.4.1)
# Requirement already satisfied: acvl-utils<0.3,>=0.2 in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from nnunetv2) (0.2)
# Requirement already satisfied: dynamic-network-architectures<0.4,>=0.3.1 in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from nnunetv2) (0.3.1)
# Requirement already satisfied: tqdm in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (4.66.5)
# Requirement already satisfied: dicom2nifti in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (2.5.0)
# Requirement already satisfied: scipy in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (1.13.1)
# Requirement already satisfied: batchgenerators>=0.25 in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from nnunetv2) (0.25)
# Requirement already satisfied: numpy in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (2.0.2)
# Requirement already satisfied: scikit-learn in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (1.5.2)
# Requirement already satisfied: scikit-image>=0.19.3 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (0.24.0)
# Requirement already satisfied: SimpleITK>=2.2.1 in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from nnunetv2) (2.3.1)
# Requirement already satisfied: pandas in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (2.2.3)
# Requirement already satisfied: graphviz in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (0.20.3)
# Requirement already satisfied: tifffile in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (2024.8.30)
# Requirement already satisfied: requests in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (2.32.3)
# Requirement already satisfied: nibabel in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (5.2.1)
# Requirement already satisfied: matplotlib in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (3.9.2)
# Requirement already satisfied: seaborn in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (0.13.2)
# Requirement already satisfied: imagecodecs in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (2024.9.22)
# Requirement already satisfied: yacs in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from nnunetv2) (0.1.8)
# Requirement already satisfied: batchgeneratorsv2>=0.2 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (0.2.1)
# Requirement already satisfied: einops in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nnunetv2) (0.8.0)
# Requirement already satisfied: connected-components-3d in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from acvl-utils<0.3,>=0.2->nnunetv2) (3.18.0)
# Requirement already satisfied: pillow>=7.1.2 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from batchgenerators>=0.25->nnunetv2) (10.4.0)
# Requirement already satisfied: future in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from batchgenerators>=0.25->nnunetv2) (1.0.0)
# Requirement already satisfied: unittest2 in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from batchgenerators>=0.25->nnunetv2) (1.1.0)
# Requirement already satisfied: threadpoolctl in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from batchgenerators>=0.25->nnunetv2) (3.5.0)
# Requirement already satisfied: fft-conv-pytorch in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from batchgeneratorsv2>=0.2->nnunetv2) (1.2.0)
# Requirement already satisfied: networkx>=2.8 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from scikit-image>=0.19.3->nnunetv2) (3.2.1)
# Requirement already satisfied: imageio>=2.33 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from scikit-image>=0.19.3->nnunetv2) (2.35.1)
# Requirement already satisfied: packaging>=21 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from scikit-image>=0.19.3->nnunetv2) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from scikit-image>=0.19.3->nnunetv2) (0.4)
# Requirement already satisfied: filelock in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (4.12.2)
# Requirement already satisfied: sympy in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (1.13.3)
# Requirement already satisfied: jinja2 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (3.1.4)
# Requirement already satisfied: fsspec in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from torch>=2.1.2->nnunetv2) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.2->nnunetv2) (12.6.77)
# Requirement already satisfied: pydicom>=2.2.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from dicom2nifti->nnunetv2) (2.4.4)
# Requirement already satisfied: python-gdcm in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from dicom2nifti->nnunetv2) (3.0.24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from matplotlib->nnunetv2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from matplotlib->nnunetv2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from matplotlib->nnunetv2) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from matplotlib->nnunetv2) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from matplotlib->nnunetv2) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from matplotlib->nnunetv2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from matplotlib->nnunetv2) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from pandas->nnunetv2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from pandas->nnunetv2) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from requests->nnunetv2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from requests->nnunetv2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from requests->nnunetv2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from requests->nnunetv2) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from scikit-learn->nnunetv2) (1.4.2)
# Requirement already satisfied: PyYAML in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from yacs->nnunetv2) (6.0.2)
# Requirement already satisfied: zipp>=3.1.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->nnunetv2) (3.20.2)
# Requirement already satisfied: six>=1.5 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->nnunetv2) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from jinja2->torch>=2.1.2->nnunetv2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /work/users/y/u/yuukias/Class-Homework/env_BIOS740/lib/python3.9/site-packages (from sympy->torch>=2.1.2->nnunetv2) (1.3.0)
# Collecting argparse (from unittest2->batchgenerators>=0.25->nnunetv2)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: traceback2 in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from unittest2->batchgenerators>=0.25->nnunetv2) (1.4.0)
# Requirement already satisfied: linecache2 in /nas/longleaf/home/yuukias/.local/lib/python3.9/site-packages (from traceback2->unittest2->batchgenerators>=0.25->nnunetv2) (1.0.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Define Environmental Variables
#
# nnU-Net requires the following environmental variables to be set: `nnUNet_raw`, `nnUNet_preprocessed`, `nnUNet_results`.
#
# Here we define these variables.

# %%
# Define some variables
# %env nnUNet_raw=../data/nnUNet/nnUNet_raw
# %env nnUNet_preprocessed=../data/nnUNet/nnUNet_preprocessed
# %env nnUNet_results=../data/nnUNet/nnUNet_results
# Out:
# env: nnUNet_raw=../data/nnUNet/nnUNet_raw
# env: nnUNet_preprocessed=../data/nnUNet/nnUNet_preprocessed
# env: nnUNet_results=../data/nnUNet/nnUNet_results

# %% [markdown]
# To use the dataset conversion script, we need to restore the structure of ACDC dataset. In other words, we need to make sure the target path contains extracted 'training' and 'testing' folders

# %%
import os
import shutil

# todo: Enter the same path in previous task.
path_ACDC_all = "/work/users/y/u/yuukias/Class-Homework/data/ACDC_all"
path_ACDC_separate = os.path.join(os.path.dirname(path_ACDC_all), "ACDC_separate")

if os.path.exists(path_ACDC_separate):
    shutil.rmtree(path_ACDC_separate)
os.makedirs(path_ACDC_separate)

training_path = os.path.join(path_ACDC_separate, "training")
testing_path = os.path.join(path_ACDC_separate, "testing")
os.makedirs(training_path)
os.makedirs(testing_path)

for folder in os.listdir(path_ACDC_all):
    if folder.startswith("patient"):
        patient_name = folder
        patient_id = int(patient_name.split("t")[2])
        if patient_id <= 100:
            shutil.copytree(os.path.join(path_ACDC_all, folder), os.path.join(training_path, folder))
        else:
            shutil.copytree(os.path.join(path_ACDC_all, folder), os.path.join(testing_path, folder))

# %% [markdown]
# There is a ready-to-use script that can be used to transform ACDC dataset to the desried format for nnU-Net. Please find the script and put it inside the `Task1.2` folder, renaming it as `dataset_conversion.py`.

# %%
# !python ./dataset_conversion.py -i $path_ACDC_separate
# Out:
# Converting...
# Done!

# %% [markdown]
# What is the suffix of data in `imagesTr`? What does that represent? Could you think of a case that it needs to be changed?
#
# The suffix is `0000`, which means that there is only one modality (short-axis) in the dataset. If there are multiple modalities, the suffix should be changed to represent the modality so that multi-modality training can be performed.

# %% [markdown]
# As the nnU-Net by default will train for 1000 epochs, please modify `self.num_epochs` to 200 in `<virtual env>/lib/<python>/site-packages/nnunetv2/training/nnUNetTrainer/nnUNetTrainer.py` so that the training will not take a long time.

# %% [markdown]
# As the dataset are prepared, you only need to finish the following steps to run nnU-Net on ACDC dataset.
#
# + Preprocess the dataset
# + Train the 2D model using the training set
# + Determine the best configuration of possible model. The training progress can be tracked in `nnUNet_results` folder.
# + Conduct Inference on the testing set, store the results in `labelsTs` folder.
# + Apply post-processing on the results

# %%
# !nnUNetv2_plan_and_preprocess -d 027 --verify_dataset_integrity
# Out:
# Fingerprint extraction...
# Dataset027_ACDC
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x
../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient099_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55d41702af30): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient099_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56534a36f900): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient099_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56534a36f900): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient099_frame09.nii.gz has unexpected scales in sform
#
#  97%|███████████████████████████████████████▊ | 194/200 [00:28<00:00, 10.77it/s]WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55c978677500): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/imagesTr/patient100_frame01_0000.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55c978677500): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/imagesTr/patient100_frame01_0000.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55c977a338b0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient100_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55c977a338b0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient100_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x558978e18bb0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/imagesTr/patient100_frame13_0000.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x558978e18bb0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/imagesTr/patient100_frame13_0000.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x5589781d4f60): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient100_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x5589781d4f60): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient100_frame13.nii.gz has unexpected scales in sform
#
# 100%|█████████████████████████████████████████| 200/200 [00:29<00:00,  6.72it/s]
# Configuration: 3d_lowres...
# INFO: Configuration 3d_lowres not found in plans file nnUNetPlans.json of dataset Dataset027_ACDC. Skipping.

# %%
# !nnUNetv2_train 027 2d all --npz

# %%
# !nnUNetv2_find_best_configuration 027 -c 2d
# Out:
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient001_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient004_frame15.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient001_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient004_frame15.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient008_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient008_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient011_frame08.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient005_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient001_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient005_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient011_frame08.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient001_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient005_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient005_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient008_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient008_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient012_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient012_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient002_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient002_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient006_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient006_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient012_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient012_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient015_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient015_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient009_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient009_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient002_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient002_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient018_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient018_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient013_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient022_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient013_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient022_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient006_frame16.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient006_frame16.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient015_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient015_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient009_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient009_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient019_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient003_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient019_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient003_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient022_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient022_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient013_frame14.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient013_frame14.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient016_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient016_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient010_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f7ee6d6b20): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient025_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient010_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f7ee6d6b20): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient025_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient023_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient023_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient019_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient003_frame15.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient019_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient003_frame15.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient007_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient014_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient007_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient014_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient016_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient010_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient023_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56044ef0d670): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient010_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient016_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x557988a69570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient023_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient020_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient020_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient007_frame07.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f7ee6d6b20): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient026_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f836f04570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient007_frame07.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient014_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f7ee6d6b20): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient026_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55de60c4e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient014_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient004_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56266016e570): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient004_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient017_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564b497d5ea0): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient017_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient020_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x56516631a060): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient020_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55
frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f7ee6d6b20): ../data/nnUNet/nnUNet_raw/Dataset027_ACDC/labelsTr/patient054_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# ...
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient085_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562b7b5c3570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient077_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55968be93570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient081_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562b7b5c3570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient077_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient095_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient095_frame12.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient089_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient089_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient099_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x556b1cf568f0): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient084_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient099_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x556b1cf568f0): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient084_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient092_frame06.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient092_frame06.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient086_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient096_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient086_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient096_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient089_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient089_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient099_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient099_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient093_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient093_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient086_frame08.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient086_frame08.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient090_frame04.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient090_frame04.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient100_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient096_frame08.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient100_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient096_frame08.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient087_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient093_frame14.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient087_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient093_frame14.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient090_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient090_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient100_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55702b09a210): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient100_frame13.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient097_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient094_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient097_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient087_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient094_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient087_frame10.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient091_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient091_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient094_frame07.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient088_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient094_frame07.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x562ee0081060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient088_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient091_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555b5693e060): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient091_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient097_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient097_frame11.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient095_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x55f58cb02570): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient095_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient098_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient098_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient098_frame09.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x555879320620): ../data/nnUNet/nnUNet_preprocessed/Dataset027_ACDC/gt_segmentations/patient098_frame09.nii.gz has unexpected scales in sform
#
# Results were improved by removing all but the largest component for 3. Dice before: 0.94379 after: 0.9455
#
# ***Run inference like this:***
#
# nnUNetv2_predict -d Dataset027_ACDC -i INPUT_FOLDER -o OUTPUT_FOLDER -f  0 1 2 3 4 -tr nnUNetTrainer -c 2d -p nnUNetPlans
#
# ***Once inference is completed, run postprocessing like this:***
#
# nnUNetv2_apply_postprocessing -i OUTPUT_FOLDER -o OUTPUT_FOLDER_PP -pp_pkl_file ../data/nnUNet/nnUNet_results/Dataset027_ACDC/nnUNetTrainer__nnUNetPlans__2d/crossval_results_folds_0_1_2_3_4/postprocessing.pkl -np 8 -plans_json ../data/nnUNet/nnUNet_results/Dataset027_ACDC/nnUNetTrainer__nnUNetPlans__2d/crossval_results_folds_0_1_2_3_4/plans.json

# %%
path_ACDC_testing_image = os.path.join("../data/nnUNet/nnUNet_raw/Dataset027_ACDC/", "imagesTs")
path_ACDC_testing_label = os.path.join("../data/nnUNet/nnUNet_raw/Dataset027_ACDC/", "labelsTs")
# post processsed
path_ACDC_testing_label_pp = os.path.join("../data/nnUNet/nnUNet_raw/Dataset027_ACDC/", "labelsTs_PP")
os.makedirs(path_ACDC_testing_label, exist_ok=True)
os.makedirs(path_ACDC_testing_label_pp, exist_ok=True)

# %%
# !nnUNetv2_predict -d Dataset027_ACDC -i $path_ACDC_testing_image -o $path_ACDC_testing_label -f  0 1 2 3 4 -tr nnUNetTrainer -c 2d -p nnUNetPlans

# %%
# !nnUNetv2_apply_postprocessing -i $path_ACDC_testing_label -o $path_ACDC_testing_label_pp -pp_pkl_file $nnUNet_results/Dataset027_ACDC/nnUNetTrainer__nnUNetPlans__2d/crossval_results_folds_0_1_2_3_4/postprocessing.pkl -np 8 -plans_json $nnUNet_results/Dataset027_ACDC/nnUNetTrainer__nnUNetPlans__2d/crossval_results_folds_0_1_2_3_4/plans.json

# %% [markdown]
# Use `torchmetrics` to calculate the Dice and Jaccard index as previous task for the last 30 patients after post-processing (121~150). Report the scores.

# %%
import random
import numpy as np
import torchmetrics
import torch

# Set the seed for reproducibility
torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
random.seed(0)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cpu

# %%
import sys

sys.path.append("..")
import nibabel as nib
from tqdm import tqdm
from utils.Task1_utils import load_config

config = load_config("../config/Task1.1_config.yaml")
NUM_CLASSES = config["dataset"]["number_classes"]
metrics = torchmetrics.MetricCollection(
    [
        # todo Evaluate Dice and Jaccard Index
        torchmetrics.Dice(
            num_classes=NUM_CLASSES, ignore_index=0
        ),  # 'micro' by default
        torchmetrics.JaccardIndex(
            task="multiclass", num_classes=NUM_CLASSES, ignore_index=0
        ),  # IoU, 'macro' by default
    ],
    prefix="metrics/",
)
test_metrics = metrics.clone(prefix="test_metrics/").to(device)
test_evaluator = test_metrics.clone().to(device)

for file in tqdm(os.listdir(path_ACDC_testing_label_pp)):
    if file.startswith("patient"):
        patient_name = file.split(".")[0]
        patient_id = int(patient_name.split("_")[0].split("t")[2])
        frame = patient_name.split("_")[1].split("e")[1]
        if patient_id > 120:
            # image_data = nib.load(os.path.join(path_ACDC_testing_image, f"{patient_name}_0000.nii.gz")).get_fdata()
            mask_data = nib.load(
                os.path.join(
                    path_ACDC_all,
                    f"patient{patient_id}",
                    f"patient{patient_id}_frame{frame}_gt.nii.gz",
                )
            ).get_fdata()
            pred_data = nib.load(
                os.path.join(path_ACDC_testing_label_pp, f"{patient_name}.nii.gz")
            ).get_fdata()
            for s in range(mask_data.shape[2]):
                preds_ = torch.from_numpy(pred_data[:, :, s].astype(np.uint8))
                masks_ = torch.from_numpy(mask_data[:, :, s].astype(np.uint8))
                test_evaluator.update(preds_, masks_)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:05<00:00, 19.43it/s]

# %%
print(test_evaluator.compute())
# Out:
# {'test_metrics/Dice': tensor(0.9340), 'test_metrics/MulticlassJaccardIndex': tensor(0.9032)}

# %% [markdown]
# Please report the Dice and Jaccard Index score for nnUNet. How does it compare to the vanilla U-Net?

# %% [markdown]
# Metrics:
#
# U-Net: Dice-0.8630, JaccardIndex-0.8061
#
# nnU-Net: Dice-0.9340, JaccardIndex-0.9032
